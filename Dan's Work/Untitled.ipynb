# %%
import requests

url = "https://free-nba.p.rapidapi.com/players"

querystring = {"page":"0","per_page":"25","search":"davis"}

headers = {
    'x-rapidapi-host': "free-nba.p.rapidapi.com",
    'x-rapidapi-key': "945070f3fbmsh5c886d1719c818dp1891e5jsn35de5214db8b"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"data":[{"id":119,"first_name":"Tyler","height_feet":null,"height_inches":null,"last_name":"Davis","position":"C","team":{"id":21,"abbreviation":"OKC","city":"Oklahoma City","conference":"West","division":"Northwest","full_name":"Oklahoma City Thunder","name":"Thunder"},"weight_pounds":null},{"id":619,"first_name":"Walter","height_feet":null,"height_inches":null,"last_name":"Davis","position":"","team":{"id":8,"abbreviation":"DEN","city":"Denver","conference":"West","division":"Northwest","full_name":"Denver Nuggets","name":"Nuggets"},"weight_pounds":null},{"id":622,"first_name":"Terry","height_feet":null,"height_inches":null,"last_name":"Davis","position":"","team":{"id":16,"abbreviation":"MIA","city":"Miami","conference":"East","division":"Southeast","full_name":"Miami Heat","name":"Heat"},"weight_pounds":null},{"id":700,"first_name":"Dale","height_feet":null,"height_inches":null,"last_name":"Davis","position":"","team":{"id":12,"abbreviation":"IND","city":"Indiana","conference":"
# ...

# %%
import requests

url = "https://free-nba.p.rapidapi.com/players/2544"

headers = {
    'x-rapidapi-host': "free-nba.p.rapidapi.com",
    'x-rapidapi-key': "945070f3fbmsh5c886d1719c818dp1891e5jsn35de5214db8b"
    }

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# {"id":2544,"first_name":"Wayne","height_feet":null,"height_inches":null,"last_name":"Kreklow","position":"","team":{"id":2,"abbreviation":"BOS","city":"Boston","conference":"East","division":"Atlantic","full_name":"Boston Celtics","name":"Celtics"},"weight_pounds":null}

# %%
import requests

url = "https://free-nba.p.rapidapi.com/stats"

querystring = {"dates":"2017-11-19","page":"0","per_page":"25"}

headers = {
    'x-rapidapi-host': "free-nba.p.rapidapi.com",
    'x-rapidapi-key': "945070f3fbmsh5c886d1719c818dp1891e5jsn35de5214db8b"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
result = response.json()

# %%
list_of_dates = ["2017-11-15","2017-11-16","2017-11-17","2017-11-18","2017-11-19","2017-11-20","2017-11-21"
                "2017-11-22","2017-11-23","2017-11-24","2017-11-25","2017-11-26","2017-11-27","2017-11-28"]

# %%
def update_date(date):
    querystring["dates"] = date

# %%
results = []

# %%
for i in list(range(0,len(list_of_dates))):
    update_date(list_of_dates[i])
    response = requests.request("GET", url, headers=headers, params=querystring)
    result = response.json()
    results.append(result)

# %%
import pandas as pd
a = pd.DataFrame()

# %%
results
# Out:
# [{'data': [{'id': 1069008,
#     'ast': 0,
#     'blk': 1,
#     'dreb': 2,
#     'fg3_pct': 0.2,
#     'fg3a': 5,
#     'fg3m': 1,
#     'fg_pct': 0.333,
#     'fga': 9,
#     'fgm': 3,
#     'ft_pct': 0.0,
#     'fta': 0,
#     'ftm': 0,
#     'game': {'id': 45237,
#      'date': '2019-01-17T00:00:00.000Z',
#      'home_team_id': 4,
#      'home_team_score': 114,
#      'period': 4,
#      'postseason': False,
#      'season': 2018,
#      'status': 'Final',
#      'time': ' ',
#      'visitor_team_id': 26,
#      'visitor_team_score': 95},
#     'min': '20:08',
#     'oreb': 0,
#     'pf': 0,
#     'player': {'id': 415,
#      'first_name': 'Iman',
#      'height_feet': 6,
#      'height_inches': 5,
#      'last_name': 'Shumpert',
#      'position': 'G',
#      'team_id': 11,
#      'weight_pounds': 215},
#     'pts': 7,
#     'reb': 2,
#     'stl': 0,
#     'team': {'id': 26,
#      'abbreviation': 'SAC',
#      'city': 'Sacramento',
#      'conference': 'West',
# ...

# %%
print(result)
# Out:
# {'data': [{'id': 1069008, 'ast': 0, 'blk': 1, 'dreb': 2, 'fg3_pct': 0.2, 'fg3a': 5, 'fg3m': 1, 'fg_pct': 0.333, 'fga': 9, 'fgm': 3, 'ft_pct': 0.0, 'fta': 0, 'ftm': 0, 'game': {'id': 45237, 'date': '2019-01-17T00:00:00.000Z', 'home_team_id': 4, 'home_team_score': 114, 'period': 4, 'postseason': False, 'season': 2018, 'status': 'Final', 'time': ' ', 'visitor_team_id': 26, 'visitor_team_score': 95}, 'min': '20:08', 'oreb': 0, 'pf': 0, 'player': {'id': 415, 'first_name': 'Iman', 'height_feet': 6, 'height_inches': 5, 'last_name': 'Shumpert', 'position': 'G', 'team_id': 11, 'weight_pounds': 215}, 'pts': 7, 'reb': 2, 'stl': 0, 'team': {'id': 26, 'abbreviation': 'SAC', 'city': 'Sacramento', 'conference': 'West', 'division': 'Pacific', 'full_name': 'Sacramento Kings', 'name': 'Kings'}, 'turnover': 2}, {'id': 1069009, 'ast': 4, 'blk': 0, 'dreb': 5, 'fg3_pct': 0.0, 'fg3a': 2, 'fg3m': 0, 'fg_pct': 0.2, 'fga': 5, 'fgm': 1, 'ft_pct': 0.0, 'fta': 0, 'ftm': 0, 'game': {'id': 45237, 'date': '2019-01-
# ...

# %%
result.keys()
# Out:
# dict_keys(['data', 'meta'])

# %%
result['data'][0]
# Out:
# {'id': 1069008,
#  'ast': 0,
#  'blk': 1,
#  'dreb': 2,
#  'fg3_pct': 0.2,
#  'fg3a': 5,
#  'fg3m': 1,
#  'fg_pct': 0.333,
#  'fga': 9,
#  'fgm': 3,
#  'ft_pct': 0.0,
#  'fta': 0,
#  'ftm': 0,
#  'game': {'id': 45237,
#   'date': '2019-01-17T00:00:00.000Z',
#   'home_team_id': 4,
#   'home_team_score': 114,
#   'period': 4,
#   'postseason': False,
#   'season': 2018,
#   'status': 'Final',
#   'time': ' ',
#   'visitor_team_id': 26,
#   'visitor_team_score': 95},
#  'min': '20:08',
#  'oreb': 0,
#  'pf': 0,
#  'player': {'id': 415,
#   'first_name': 'Iman',
#   'height_feet': 6,
#   'height_inches': 5,
#   'last_name': 'Shumpert',
#   'position': 'G',
#   'team_id': 11,
#   'weight_pounds': 215},
#  'pts': 7,
#  'reb': 2,
#  'stl': 0,
#  'team': {'id': 26,
#   'abbreviation': 'SAC',
#   'city': 'Sacramento',
#   'conference': 'West',
#   'division': 'Pacific',
#   'full_name': 'Sacramento Kings',
#   'name': 'Kings'},
#  'turnover': 2}
