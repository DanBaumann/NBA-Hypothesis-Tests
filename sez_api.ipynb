# %%
import pandas as pd
import numpy as np
import sqlite3
import requests

# %%
a = requests.request("GET", "https://api.nytimes.com/svc/mostpopular/v2/viewed/1.json?api-key=7Gi5KuDrrDS5mevrHFFslepba6UUXRTN")

# %%
a.json()
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2019 The New York Times Company.  All Rights Reserved.',
#  'num_results': 1505,
#  'results': [{'url': 'https://www.nytimes.com/2019/11/07/opinion/nike-running-mary-cain.html',
#    'adx_keywords': 'Cain, Mary (1996- );NIKE Inc;Women and Girls;Weight;Running;Track and Field;Salazar, Alberto;Doping (Sports);Coaches and Managers;#MeToo Movement;Oregon;your-feed-opinionvideo',
#    'column': None,
#    'section': 'Opinion',
#    'byline': 'By MARY CAIN',
#    'type': 'Article',
#    'title': 'I Was the Fastest Girl in America, Until I Joined Nike',
#    'abstract': 'Mary Cain’s male coaches were convinced she had to get “thinner, and thinner, and thinner.” Then her body started breaking down.',
#    'published_date': '2019-11-07',
#    'source': 'The New York Times',
#    'id': 100000006790443,
#    'asset_id': 100000006790443,
#    'views': 1,
#    'des_facet': ['WOMEN AND GIRLS',
#     'RUNNING',
#     'TRACK AND FIELD',
# ...

# %%
url = "https://bloomberg-market-and-financial-news.p.rapidapi.com/market/get-full"

querystring = {"id":"adsmi:ind,aex:ind,co1:com,gc1:com"}

headers = {
    'x-rapidapi-host': "bloomberg-market-and-financial-news.p.rapidapi.com",
    'x-rapidapi-key': "50f7c287bfmsh6c8bbf85917853dp1652a3jsn2d07f8e8b1a6"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"message":"You are not subscribed to this API."}

# %%
url = "https://apidojo-yahoo-finance-v1.p.rapidapi.com/market/get-summary"

querystring = {"region":"US","lang":"en"}

headers = {
    'x-rapidapi-host': "apidojo-yahoo-finance-v1.p.rapidapi.com",
    'x-rapidapi-key': "dc05326e6dmsh6aaea24caecbaf9p10efaajsn9e320a0a46d1"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"message":"You are not subscribed to this API."}

# %%
url = "https://free-nba.p.rapidapi.com/teams"

querystring = {"page":"0"}

headers = {
    'x-rapidapi-host': "free-nba.p.rapidapi.com",
    'x-rapidapi-key': "dc05326e6dmsh6aaea24caecbaf9p10efaajsn9e320a0a46d1"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'data': [{'id': 1,
#    'abbreviation': 'ATL',
#    'city': 'Atlanta',
#    'conference': 'East',
#    'division': 'Southeast',
#    'full_name': 'Atlanta Hawks',
#    'name': 'Hawks'},
#   {'id': 2,
#    'abbreviation': 'BOS',
#    'city': 'Boston',
#    'conference': 'East',
#    'division': 'Atlantic',
#    'full_name': 'Boston Celtics',
#    'name': 'Celtics'},
#   {'id': 3,
#    'abbreviation': 'BKN',
#    'city': 'Brooklyn',
#    'conference': 'East',
#    'division': 'Atlantic',
#    'full_name': 'Brooklyn Nets',
#    'name': 'Nets'},
#   {'id': 4,
#    'abbreviation': 'CHA',
#    'city': 'Charlotte',
#    'conference': 'East',
#    'division': 'Southeast',
#    'full_name': 'Charlotte Hornets',
#    'name': 'Hornets'},
#   {'id': 5,
#    'abbreviation': 'CHI',
#    'city': 'Chicago',
#    'conference': 'East',
#    'division': 'Central',
#    'full_name': 'Chicago Bulls',
#    'name': 'Bulls'},
#   {'id': 6,
#    'abbreviation': 'CLE',
#    'city': 'Cleveland',
# ...

# %%
url = "https://free-nba.p.rapidapi.com/games"

querystring = {"page":"0","per_page":"25", "date": "2018-02-05"}

headers = {
    'x-rapidapi-host': "free-nba.p.rapidapi.com",
    'x-rapidapi-key': "dc05326e6dmsh6aaea24caecbaf9p10efaajsn9e320a0a46d1"
    }

response = requests.request("GET", url, headers=headers, params=querystring,)

# %%
response
# Out:
# <Response [200]>

# %%
a = response.json()

# %%
a.keys()
# Out:
# dict_keys(['data', 'meta'])

# %%
a['data']
# Out:
# [{'id': 47179,
#   'date': '2019-01-30T00:00:00.000Z',
#   'home_team': {'id': 2,
#    'abbreviation': 'BOS',
#    'city': 'Boston',
#    'conference': 'East',
#    'division': 'Atlantic',
#    'full_name': 'Boston Celtics',
#    'name': 'Celtics'},
#   'home_team_score': 126,
#   'period': 4,
#   'postseason': False,
#   'season': 2018,
#   'status': 'Final',
#   'time': ' ',
#   'visitor_team': {'id': 4,
#    'abbreviation': 'CHA',
#    'city': 'Charlotte',
#    'conference': 'East',
#    'division': 'Southeast',
#    'full_name': 'Charlotte Hornets',
#    'name': 'Hornets'},
#   'visitor_team_score': 94},
#  {'id': 48751,
#   'date': '2019-02-09T00:00:00.000Z',
#   'home_team': {'id': 2,
#    'abbreviation': 'BOS',
#    'city': 'Boston',
#    'conference': 'East',
#    'division': 'Atlantic',
#    'full_name': 'Boston Celtics',
#    'name': 'Celtics'},
#   'home_team_score': 112,
#   'period': 4,
#   'postseason': False,
#   'season': 2018,
#   'status': 'Final',
# ...

# %%
url = "https://free-nba.p.rapidapi.com/games"

querystring = {"page":"0","per_page":"25", "dates": "2017-11-19"}

headers = {
    'x-rapidapi-host': "free-nba.p.rapidapi.com",
    'x-rapidapi-key': "dc05326e6dmsh6aaea24caecbaf9p10efaajsn9e320a0a46d1"
    }

response = requests.request("GET", url, headers=headers, params=querystring,)

# %%
response.json()
# Out:
# {'data': [{'id': 47179,
#    'date': '2019-01-30T00:00:00.000Z',
#    'home_team': {'id': 2,
#     'abbreviation': 'BOS',
#     'city': 'Boston',
#     'conference': 'East',
#     'division': 'Atlantic',
#     'full_name': 'Boston Celtics',
#     'name': 'Celtics'},
#    'home_team_score': 126,
#    'period': 4,
#    'postseason': False,
#    'season': 2018,
#    'status': 'Final',
#    'time': ' ',
#    'visitor_team': {'id': 4,
#     'abbreviation': 'CHA',
#     'city': 'Charlotte',
#     'conference': 'East',
#     'division': 'Southeast',
#     'full_name': 'Charlotte Hornets',
#     'name': 'Hornets'},
#    'visitor_team_score': 94},
#   {'id': 48751,
#    'date': '2019-02-09T00:00:00.000Z',
#    'home_team': {'id': 2,
#     'abbreviation': 'BOS',
#     'city': 'Boston',
#     'conference': 'East',
#     'division': 'Atlantic',
#     'full_name': 'Boston Celtics',
#     'name': 'Celtics'},
#    'home_team_score': 112,
#    'period': 4,
#    'postseason': False,
# ...
