# %%
import sqlite3
import pandas as pd 
import numpy as np

# %%
stats = pd.read_csv("./nba-players-stats/Seasons_Stats.csv")

# %%
stats.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP',
#        'PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%',
#        'BLK%', 'TOV%', 'USG%', 'blanl', 'OWS', 'DWS', 'WS', 'WS/48', 'blank2',
#        'OBPM', 'DBPM', 'BPM', 'VORP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%',
#        '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB',
#        'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24691 entries, 0 to 24690
# Data columns (total 53 columns):
# Unnamed: 0    24691 non-null int64
# Year          24624 non-null float64
# Player        24624 non-null object
# Pos           24624 non-null object
# Age           24616 non-null float64
# Tm            24624 non-null object
# G             24624 non-null float64
# GS            18233 non-null float64
# MP            24138 non-null float64
# PER           24101 non-null float64
# TS%           24538 non-null float64
# 3PAr          18839 non-null float64
# FTr           24525 non-null float64
# ORB%          20792 non-null float64
# DRB%          20792 non-null float64
# TRB%          21571 non-null float64
# AST%          22555 non-null float64
# STL%          20792 non-null float64
# BLK%          20792 non-null float64
# TOV%          19582 non-null float64
# USG%          19640 non-null float64
# blanl         0 non-null float64
# ...

# %%
df = stats.loc[((stats['Year'] <= 2017.0) & (stats['Year'] > 1997.0 ))]

# %%
df.shape
# Out:
# (11258, 53)

# %%
df['']

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP',
#        'PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%',
#        'BLK%', 'TOV%', 'USG%', 'blanl', 'OWS', 'DWS', 'WS', 'WS/48', 'blank2',
#        'OBPM', 'DBPM', 'BPM', 'VORP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%',
#        '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB',
#        'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df1 =df[['Player','Pos','FG', 'FGA', 'FG%', '3P', '3PA', '3P%',
       '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB',
       'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'G']]
df1.tail()
# Out:
#                   Player Pos     FG    FGA    FG%    3P   3PA    3P%     2P  \
# 24686        Cody Zeller  PF  253.0  443.0  0.571   0.0   1.0  0.000  253.0
# 24687       Tyler Zeller   C   78.0  158.0  0.494   0.0   1.0  0.000   78.0
# 24688  Stephen Zimmerman   C   10.0   31.0  0.323   0.0   0.0    NaN   10.0
# 24689        Paul Zipser  SF   88.0  221.0  0.398  33.0  99.0  0.333   55.0
# 24690        Ivica Zubac   C  126.0  238.0  0.529   0.0   3.0  0.000  126.0
#
#          2PA  ...    ORB    DRB    TRB   AST   STL   BLK   TOV     PF    PTS  \
# 24686  442.0  ...  135.0  270.0  405.0  99.0  62.0  58.0  65.0  189.0  639.0
# 24687  157.0  ...   43.0   81.0  124.0  42.0   7.0  21.0  20.0   61.0  178.0
# 24688   31.0  ...   11.0   24.0   35.0   4.0   2.0   5.0   3.0   17.0   23.0
# 24689  122.0  ...   15.0  110.0  125.0  36.0  15.0  16.0  40.0   78.0  240.0
# 24690  235.0  ...   41.0  118.0  159.0  30.0  14.0  33.0  30.0   66.0  284.0
#
#           G
# 24686  62.0
# 24687  51.0
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11258 entries, 13414 to 24690
# Data columns (total 25 columns):
# Player    11258 non-null object
# Pos       11258 non-null object
# FG        11258 non-null float64
# FGA       11258 non-null float64
# FG%       11198 non-null float64
# 3P        11258 non-null float64
# 3PA       11258 non-null float64
# 3P%       9282 non-null float64
# 2P        11258 non-null float64
# 2PA       11258 non-null float64
# 2P%       11175 non-null float64
# eFG%      11198 non-null float64
# FT        11258 non-null float64
# FTA       11258 non-null float64
# FT%       10758 non-null float64
# ORB       11258 non-null float64
# DRB       11258 non-null float64
# TRB       11258 non-null float64
# AST       11258 non-null float64
# STL       11258 non-null float64
# BLK       11258 non-null float64
# TOV       11258 non-null float64
# PF        11258 non-null float64
# PTS       11258 non-null float64
# G         11258 non-null float64
# ...

# %%
df2 = df1.dropna()

# %%
df3 = df2.reset_index(drop=True)

# %%
df3.head()
# Out:
#                 Player Pos     FG     FGA    FG%    3P    3PA    3P%     2P  \
# 0   Mahmoud Abdul-Rauf  PG  103.0   273.0  0.377   5.0   31.0  0.161   98.0
# 1    Tariq Abdul-Wahad  SG  144.0   357.0  0.403   4.0   19.0  0.211  140.0
# 2  Shareef Abdur-Rahim  SF  653.0  1347.0  0.485  21.0   51.0  0.412  632.0
# 3       Cory Alexander  PG  171.0   400.0  0.428  66.0  176.0  0.375  105.0
# 4       Cory Alexander  PG   60.0   145.0  0.414  20.0   64.0  0.313   40.0
#
#       2PA  ...    ORB    DRB    TRB    AST   STL   BLK    TOV     PF     PTS  \
# 0   242.0  ...    6.0   31.0   37.0   58.0  16.0   1.0   19.0   31.0   227.0
# 1   338.0  ...   44.0   72.0  116.0   51.0  35.0  13.0   65.0   81.0   376.0
# 2  1296.0  ...  227.0  354.0  581.0  213.0  89.0  76.0  257.0  201.0  1829.0
# 3   224.0  ...   17.0  129.0  146.0  209.0  70.0  11.0  112.0   98.0   488.0
# 4    81.0  ...    7.0   40.0   47.0   71.0  25.0   5.0   47.0   53.0   165.0
#
#       G
# 0  31.0
# 1  59.0
# 2  82.0
# ...

# %%
print(df3.iloc[4]['Player'])
print(df3.iloc[3]['Player'])
df3.iloc[4]['Player'] == df3.iloc[3]['Player']
# Out:
# Cory Alexander
# Cory Alexander
# True

# %%
len(df3.Player.unique())
# Out:
# 1558

# %%
columns = list(df3.columns)

# %%
df3['ORB/G'] = round(df3['ORB']/df3['G'],2)
df3['DRB/G'] = round(df3['DRB']/df3['G'],2)
df3['TRB/G'] = round(df3['TRB']/df3['G'],2)
df3['AST/G'] = round(df3['AST']/df3['G'],2)
df3['STL/G'] = round(df3['STL']/df3['G'],2)
df3['BLK/G'] = round(df3['BLK']/df3['G'],2)
df3['TOV/G'] = round(df3['TOV']/df3['G'],2)
df3['PF/G'] = round(df3['PF']/df3['G'],2)
df3['PTS/G'] = round(df3['PTS']/df3['G'],2)

# %%
df3.head()
# Out:
#                 Player Pos     FG     FGA    FG%    3P    3PA    3P%     2P  \
# 0   Mahmoud Abdul-Rauf  PG  103.0   273.0  0.377   5.0   31.0  0.161   98.0
# 1    Tariq Abdul-Wahad  SG  144.0   357.0  0.403   4.0   19.0  0.211  140.0
# 2  Shareef Abdur-Rahim  SF  653.0  1347.0  0.485  21.0   51.0  0.412  632.0
# 3       Cory Alexander  PG  171.0   400.0  0.428  66.0  176.0  0.375  105.0
# 4       Cory Alexander  PG   60.0   145.0  0.414  20.0   64.0  0.313   40.0
#
#       2PA  ...     G  ORB/G  DRB/G  TRB/G  AST/G  STL/G  BLK/G  TOV/G  PF/G  \
# 0   242.0  ...  31.0   0.19   1.00   1.19   1.87   0.52   0.03   0.61  1.00
# 1   338.0  ...  59.0   0.75   1.22   1.97   0.86   0.59   0.22   1.10  1.37
# 2  1296.0  ...  82.0   2.77   4.32   7.09   2.60   1.09   0.93   3.13  2.45
# 3   224.0  ...  60.0   0.28   2.15   2.43   3.48   1.17   0.18   1.87  1.63
# 4    81.0  ...  37.0   0.19   1.08   1.27   1.92   0.68   0.14   1.27  1.43
#
#    PTS/G
# 0   7.32
# 1   6.37
# 2  22.30
# ...

# %%
df3.columns
# Out:
# Index(['Player', 'Pos', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA',
#        '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL',
#        'BLK', 'TOV', 'PF', 'PTS', 'G', 'ORB/G', 'DRB/G', 'TRB/G', 'AST/G',
#        'STL/G', 'BLK/G', 'TOV/G', 'PF/G', 'PTS/G'],
#       dtype='object')

# %%
df4 = df3[['Player', 'Pos', 'FG%', '3P%','2P%', 'FT%','ORB/G', 'DRB/G', 'TRB/G', 'AST/G',
       'STL/G', 'BLK/G', 'TOV/G', 'PF/G', 'PTS/G']]

# %%
df4.tail()
# Out:
#               Player Pos    FG%    3P%    2P%    FT%  ORB/G  DRB/G  TRB/G  \
# 9044  Thaddeus Young  PF  0.527  0.381  0.557  0.523   1.77   4.30   6.07
# 9045     Cody Zeller  PF  0.571  0.000  0.572  0.679   2.18   4.35   6.53
# 9046    Tyler Zeller   C  0.494  0.000  0.497  0.564   0.84   1.59   2.43
# 9047     Paul Zipser  SF  0.398  0.333  0.451  0.775   0.34   2.50   2.84
# 9048     Ivica Zubac   C  0.529  0.000  0.536  0.653   1.08   3.11   4.18
#
#       AST/G  STL/G  BLK/G  TOV/G  PF/G  PTS/G
# 9044   1.65   1.54   0.41   1.30  1.82  11.00
# 9045   1.60   1.00   0.94   1.05  3.05  10.31
# 9046   0.82   0.14   0.41   0.39  1.20   3.49
# 9047   0.82   0.34   0.36   0.91  1.77   5.45
# 9048   0.79   0.37   0.87   0.79  1.74   7.47

# %%
len(df4.Player.unique())
# Out:
# 1558

# %%
df5 = df4.groupby('Player')

# %%
df5.head()
# Out:
#                    Player Pos    FG%    3P%    2P%    FT%  ORB/G  DRB/G  \
# 0      Mahmoud Abdul-Rauf  PG  0.377  0.161  0.405  1.000   0.19   1.00
# 1       Tariq Abdul-Wahad  SG  0.403  0.211  0.414  0.672   0.75   1.22
# 2     Shareef Abdur-Rahim  SF  0.485  0.412  0.488  0.784   2.77   4.32
# 3          Cory Alexander  PG  0.428  0.375  0.469  0.784   0.28   2.15
# 4          Cory Alexander  PG  0.414  0.313  0.494  0.676   0.19   1.08
# ...                   ...  ..    ...    ...    ...    ...    ...    ...
# 9042            Joe Young  PG  0.361  0.217  0.429  0.733   0.03   0.48
# 9045          Cody Zeller  PF  0.571  0.000  0.572  0.679   2.18   4.35
# 9046         Tyler Zeller   C  0.494  0.000  0.497  0.564   0.84   1.59
# 9047          Paul Zipser  SF  0.398  0.333  0.451  0.775   0.34   2.50
# 9048          Ivica Zubac   C  0.529  0.000  0.536  0.653   1.08   3.11
#
#       TRB/G  AST/G  STL/G  BLK/G  TOV/G  PF/G  PTS/G
# ...

# %%
df6 = df4.groupby('Player')[['FG%', '3P%','2P%', 'FT%','ORB/G', 'DRB/G', 'TRB/G', 'AST/G',
       'STL/G', 'BLK/G', 'TOV/G', 'PF/G', 'PTS/G']].mean()

# %%
df7 = df6.round(3)

# %%
df7.tail()
# Out:
#                       FG%    3P%    2P%    FT%  ORB/G  DRB/G  TRB/G  AST/G  \
# Player
# Zarko Cabarkapa     0.441  0.290  0.473  0.750  0.728  1.540  2.268  0.612
# Zaza Pachulia       0.468  0.000  0.472  0.752  2.389  3.814  6.203  1.445
# Zoran Dragic        0.342  0.182  0.543  0.589  0.313  0.187  0.500  0.293
# Zoran Planinic      0.407  0.296  0.447  0.676  0.327  1.023  1.347  1.120
# Zydrunas Ilgauskas  0.476  0.140  0.478  0.774  2.839  4.377  7.218  1.101
#
#                     STL/G  BLK/G  TOV/G   PF/G   PTS/G
# Player
# Zarko Cabarkapa     0.232  0.160  0.808  1.507   4.885
# Zaza Pachulia       0.765  0.359  1.480  2.622   7.477
# Zoran Dragic        0.107  0.000  0.270  0.350   1.650
# Zoran Planinic      0.403  0.043  0.817  1.607   3.860
# Zydrunas Ilgauskas  0.493  1.545  1.798  3.258  12.745

# %%
df7['POS'] = df5['Pos'].unique()

# %%
df7.tail()
# Out:
#                       FG%    3P%    2P%    FT%  ORB/G  DRB/G  TRB/G  AST/G  \
# Player
# Zarko Cabarkapa     0.441  0.290  0.473  0.750  0.728  1.540  2.268  0.612
# Zaza Pachulia       0.468  0.000  0.472  0.752  2.389  3.814  6.203  1.445
# Zoran Dragic        0.342  0.182  0.543  0.589  0.313  0.187  0.500  0.293
# Zoran Planinic      0.407  0.296  0.447  0.676  0.327  1.023  1.347  1.120
# Zydrunas Ilgauskas  0.476  0.140  0.478  0.774  2.839  4.377  7.218  1.101
#
#                     STL/G  BLK/G  TOV/G   PF/G   PTS/G       POS
# Player
# Zarko Cabarkapa     0.232  0.160  0.808  1.507   4.885      [PF]
# Zaza Pachulia       0.765  0.359  1.480  2.622   7.477       [C]
# Zoran Dragic        0.107  0.000  0.270  0.350   1.650      [SG]
# Zoran Planinic      0.403  0.043  0.817  1.607   3.860  [SG, PG]
# Zydrunas Ilgauskas  0.493  1.545  1.798  3.258  12.745       [C]

# %%
df8 = df7

# %%
df8['POS'] = df8['POS'].map(lambda x: x[0])

# %%
df8.POS
# Out:
# Player
# A.C. Green                PF
# A.J. Guyton               PG
# A.J. Hammons               C
# A.J. Price                PG
# Aaron Brooks              PG
# Aaron Gordon              PF
# Aaron Gray                 C
# Aaron Harrison            SG
# Aaron McKie            SG-SF
# Aaron Williams            PF
# Acie Law                  PG
# Adam Harrington           SG
# Adam Keefe                PF
# Adam Morrison             PF
# Adonal Foyle               C
# Adonis Jordan             PG
# Adonis Thomas             SF
# Adreian Payne             PF
# Adrian Griffin            SG
# Al Harrington             PF
# Al Horford                 C
# Al Jefferson              PF
# Al Thornton               PF
# Al-Farouq Aminu           SF
# Alan Anderson             SF
# Alan Henderson            PF
# Alan Williams              C
# Alando Tucker             SF
# Alec Burks                SG
# Alex Abrines              SG
#                        ...
# Will Cherry               PG
# ...

# %%
df8.head()
# Out:
#                 FG%    3P%    2P%    FT%  ORB/G  DRB/G  TRB/G  AST/G  STL/G  \
# Player
# A.C. Green    0.442  0.062  0.448  0.675  1.890  3.722  5.615  0.865  0.633
# A.J. Guyton   0.384  0.382  0.381  0.824  0.285  0.750  1.035  1.870  0.245
# A.J. Hammons  0.405  0.500  0.375  0.450  0.360  1.270  1.640  0.180  0.050
# A.J. Price    0.373  0.273  0.447  0.632  0.251  1.093  1.344  1.971  0.401
# Aaron Brooks  0.410  0.359  0.444  0.838  0.403  1.268  1.671  3.174  0.591
#
#               BLK/G  TOV/G   PF/G  PTS/G POS
# Player
# A.C. Green    0.202  0.602  1.572  5.440  PF
# A.J. Guyton   0.155  0.775  0.785  5.710  PG
# A.J. Hammons  0.590  0.450  0.950  2.180   C
# A.J. Price    0.021  0.753  0.735  5.578  PG
# Aaron Brooks  0.134  1.582  1.932  9.604  PG

# %%
players = pd.read_csv("Sez/Players.csv.xls")
players.head()
type(players)
# Out:
# pandas.core.frame.DataFrame

# %%
players.columns
# Out:
# Index(['Unnamed: 0', 'Player', 'height', 'weight', 'collage', 'born',
#        'birth_city', 'birth_state'],
#       dtype='object')

# %%
players1 = players.drop('Unnamed: 0', axis=1)

players1.head()
# Out:
#             Player  height  weight                          collage    born  \
# 0  Curly Armstrong   180.0    77.0               Indiana University  1918.0
# 1     Cliff Barker   188.0    83.0           University of Kentucky  1921.0
# 2    Leo Barnhorst   193.0    86.0         University of Notre Dame  1924.0
# 3       Ed Bartels   196.0    88.0  North Carolina State University  1925.0
# 4      Ralph Beard   178.0    79.0           University of Kentucky  1927.0
#
#     birth_city birth_state
# 0          NaN         NaN
# 1     Yorktown     Indiana
# 2          NaN         NaN
# 3          NaN         NaN
# 4  Hardinsburg    Kentucky

# %%
players2 = players1.drop(['collage', 'born', 'birth_city', 'birth_state'], axis=1)

# %%
final_df = pd.merge(df8,players2, on='Player', how='left')

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1558 entries, 0 to 1557
# Data columns (total 17 columns):
# Player    1558 non-null object
# FG%       1558 non-null float64
# 3P%       1558 non-null float64
# 2P%       1558 non-null float64
# FT%       1558 non-null float64
# ORB/G     1558 non-null float64
# DRB/G     1558 non-null float64
# TRB/G     1558 non-null float64
# AST/G     1558 non-null float64
# STL/G     1558 non-null float64
# BLK/G     1558 non-null float64
# TOV/G     1558 non-null float64
# PF/G      1558 non-null float64
# PTS/G     1558 non-null float64
# POS       1558 non-null object
# height    1558 non-null float64
# weight    1558 non-null float64
# dtypes: float64(15), object(2)
# memory usage: 219.1+ KB

# %%
final_df.to_csv(r'final_df.csv')
