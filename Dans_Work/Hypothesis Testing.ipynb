# %%
import pandas as pd
df = pd.read_csv('final_df.csv', index_col = 0)

# %%
df.head()
# Out:
#          Player    FG%    3P%    2P%    FT%  ORB/G  DRB/G  TRB/G  AST/G  \
# 0    A.C. Green  0.442  0.062  0.448  0.675  1.890  3.722  5.615  0.865
# 1   A.J. Guyton  0.384  0.382  0.381  0.824  0.285  0.750  1.035  1.870
# 2  A.J. Hammons  0.405  0.500  0.375  0.450  0.360  1.270  1.640  0.180
# 3    A.J. Price  0.373  0.273  0.447  0.632  0.251  1.093  1.344  1.971
# 4  Aaron Brooks  0.410  0.359  0.444  0.838  0.403  1.268  1.671  3.174
#
#    STL/G  BLK/G  TOV/G   PF/G  PTS/G POS  height  weight
# 0  0.633  0.202  0.602  1.572  5.440  PF   203.0   106.0
# 1  0.245  0.155  0.775  0.785  5.710  PG   208.0    99.0
# 2  0.050  0.590  0.450  0.950  2.180   C   198.0    99.0
# 3  0.401  0.021  0.753  0.735  5.578  PG   213.0   124.0
# 4  0.591  0.134  1.582  1.932  9.604  PG   183.0    73.0

# %%
df.loc[df['PTS/G'] > 20]
# Out:
#                   Player    FG%    3P%    2P%    FT%  ORB/G  DRB/G   TRB/G  \
# 39        Allen Iverson*  0.435  0.341  0.455  0.771  0.683  2.659   3.342
# 68        Andrew Wiggins  0.449  0.322  0.471  0.760  1.397  2.663   4.053
# 78         Anthony Davis  0.513  0.186  0.524  0.781  2.532  7.574  10.106
# 132        Blake Griffin  0.516  0.277  0.525  0.679  2.354  6.899   9.253
# 209      Carmelo Anthony  0.451  0.339  0.473  0.817  1.751  4.909   6.661
# 311       Damian Lillard  0.430  0.370  0.471  0.873  0.550  3.488   4.038
# 370     DeMarcus Cousins  0.457  0.240  0.472  0.741  2.763  8.303  11.066
# 425        Dirk Nowitzki  0.469  0.376  0.494  0.874  1.008  6.658   7.668
# 458          Dwyane Wade  0.485  0.271  0.504  0.768  1.231  3.520   4.751
# 648         James Harden  0.443  0.366  0.502  0.849  0.764  4.219   4.984
# 743          Joel Embiid  0.466  0.367  0.495  0.783  1.970  5.870   7.840
# ...
